# %%
import numpy as np
import pandas as pd
import requests
# %matplotlib inline
url='https://api.github.com/users/genzj/repos?per_page=100'

# %% [markdown]
# ### 1. 使用requests库下载数据

# %% [markdown]
# ### 2. 将数据转换成DataFrame

# %%
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/genzj/2048/{archi...     False
# 1  https://api.github.com/repos/genzj/aiohttp/{ar...     False
# 2  https://api.github.com/repos/genzj/android-ser...     False
# 3  https://api.github.com/repos/genzj/angularjs-t...     False
# 4  https://api.github.com/repos/genzj/aws-iot-dev...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/genzj/2048/assign...
# 1  https://api.github.com/repos/genzj/aiohttp/ass...
# 2  https://api.github.com/repos/genzj/android-ser...
# 3  https://api.github.com/repos/genzj/angularjs-t...
# 4  https://api.github.com/repos/genzj/aws-iot-dev...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/genzj/2048/git/bl...
# 1  https://api.github.com/repos/genzj/aiohttp/git...
# 2  https://api.github.com/repos/genzj/android-ser...
# ...

# %% [markdown]
# ### 3. 使用`full_name`作为索引

# %%
# Out:
#                                                                          archive_url  \
# full_name
# genzj/2048                         https://api.github.com/repos/genzj/2048/{archi...
# genzj/aiohttp                      https://api.github.com/repos/genzj/aiohttp/{ar...
# genzj/android-serialport-api       https://api.github.com/repos/genzj/android-ser...
# genzj/angularjs-training-exercise  https://api.github.com/repos/genzj/angularjs-t...
# genzj/aws-iot-device-sdk-js        https://api.github.com/repos/genzj/aws-iot-dev...
#
#                                    archived  \
# full_name
# genzj/2048                            False
# genzj/aiohttp                         False
# genzj/android-serialport-api          False
# genzj/angularjs-training-exercise     False
# genzj/aws-iot-device-sdk-js           False
#
#                                                                        assignees_url  \
# full_name
# ...

# %% [markdown]
# ### 4. 观察数据基本形态
# 可以直接得出：仓库数量（id-count）、star/fork最大值

# %%
# Out:
#            forks  forks_count            id  open_issues  open_issues_count  \
# count  56.000000    56.000000  5.600000e+01    56.000000          56.000000
# mean    1.482143     1.482143  6.089764e+07     0.642857           0.642857
# std     9.490648     9.490648  4.173629e+07     3.574804           3.574804
# min     0.000000     0.000000  2.322740e+06     0.000000           0.000000
# 25%     0.000000     0.000000  1.983754e+07     0.000000           0.000000
# 50%     0.000000     0.000000  6.347280e+07     0.000000           0.000000
# 75%     0.000000     0.000000  1.014597e+08     0.000000           0.000000
# max    71.000000    71.000000  1.256364e+08    25.000000          25.000000
#
#                size  stargazers_count    watchers  watchers_count
# count     56.000000         56.000000   56.000000       56.000000
# mean    1811.160714          5.696429    5.696429        5.696429
# std     2971.793121         37.953043   37.953043       37.953043
# ...

# %% [markdown]
# ### 5. 画出仓库大小直方图

# %%
# Out:
# 3920
