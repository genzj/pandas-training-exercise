# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 中文文件名导致问题
#
# 直接打开中文文件名文件，可能会触发Pandas的bug

# %%
data = pd.read_csv('数据透视表.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-97a0eabebf03> in <module>()
# ----> 1 data = pd.read_csv('数据透视表.csv')
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: Initializing from file failed

# %% [markdown]
# 比较保险的方法是使用Python原生open，将文件对象传入Pandas方法。
# 但可能因编码问题触发其他问题

# %%
with open('数据透视表.csv', 'rb') as inf:
    data = pd.read_csv(inf)
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-161e25dd0c4f> in <module>()
#       1 with open('数据透视表.csv', 'rb') as inf:
# ----> 2     data = pd.read_csv(inf)
#       3 data.head()
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# f:\venvs\data-analysis\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb6 in position 0: invalid start byte

# %% [markdown]
# 可以显式指定编码

# %%
with open('数据透视表.csv', 'rb') as inf:
    data = pd.read_csv(inf, encoding='cp936')
data.head()
# Out:
#         订购日期 所属区域  产品类别  数量         销售额          成本
# 0  3/21/2007   苏州  宠物用品  16  19,269.69   18,982.85
# 1  4/28/2007   苏州  宠物用品  40  39,465.17   40,893.08
# 2  4/28/2007   苏州  宠物用品  20  21,015.94   22,294.09
# 3  5/31/2007   苏州  宠物用品  20  23,710.26   24,318.37
# 4  6/13/2007   苏州  宠物用品  16  20,015.07   20,256.69

# %% [markdown]
# ### 类型推导问题
# Pandas类型推导可能出现错误

# %%
xls = pd.ExcelFile('test-data1.xlsx')
data = xls.parse('Sheet1')
data.head()
# Out:
#    姓名   得分
# 0  小明   98
# 1  小红   87
# 2  小白  未考核

# %% [markdown]
# 看起来是正常，但是可以看出数据类型是错误的。

# %%
data['得分']
# Out:
# 0     98
# 1     87
# 2    未考核
# Name: 得分, dtype: object

# %% [markdown]
# 解决方法1：替换所有非法值，Pandas会自动使用合适的类型

# %%
data['得分']=data['得分'].replace('未考核', np.nan)
data
# Out:
#    姓名    得分
# 0  小明  98.0
# 1  小红  87.0
# 2  小白   NaN

# %% [markdown]
# 解决方法2：打开时指定应该被替换为na的值

# %%
data = xls.parse('Sheet1', na_values='未考核')
data['得分']
# Out:
# 0    98.0
# 1    87.0
# 2     NaN
# Name: 得分, dtype: float64

# %% [markdown]
# ### 载入复杂表格

# %%
data = pd.read_table('test-data2.txt', index_col='Initial release date')

# %%
data
# Out:
#                                                               Code name  \
# Initial release date
# September 23, 2008                                        (No codename)
# February 9, 2009                     (Internally known as "Petit Four")
# April 27, 2009                                                  Cupcake
# September 15, 2009                                                Donut
# October 26, 2009                                                 Eclair
# May 20, 2010                                                      Froyo
# December 6, 2010                                            Gingerbread
# February 22, 2011                                             Honeycomb
# October 18, 2011                                     Ice Cream Sandwich
# July 9, 2012                                                 Jelly Bean
# October 31, 2013                                                 KitKat
# November 12, 2014                                              Lollipop
# October 5, 2015                                             Marshmallow
# August 22, 2016                                                  Nougat
# August 21, 2017                                                    Oreo
# NaN                                                           Android P
# NaN                   Legend:Old versionOlder version, still support...
# NaN                   # ref: https://en.wikipedia.org/wiki/Android_v...
#
#                      Version number API level  \
# Initial release date
# September 23, 2008              1.0         1
# February 9, 2009                1.1         2
# April 27, 2009                  1.5         3
# September 15, 2009              1.6         4
# October 26, 2009          2.0 – 2.1     5 – 7
# May 20, 2010            2.2 – 2.2.3         8
# December 6, 2010        2.3 – 2.3.7    9 – 10
# February 22, 2011       3.0 – 3.2.6   11 – 13
# October 18, 2011        4.0 – 4.0.4   14 – 15
# July 9, 2012            4.1 – 4.3.1   16 – 18
# October 31, 2013        4.4 – 4.4.4   19 – 20
# November 12, 2014       5.0 – 5.1.1   21 – 22
# October 5, 2015         6.0 – 6.0.1        23
# August 22, 2016         7.0 – 7.1.2   24 – 25
# August 21, 2017           8.0 – 8.1   26 – 27
# NaN                               9       NaN
# NaN                             NaN       NaN
# NaN                             NaN       NaN
#
#                                           Security patches
# Initial release date
# September 23, 2008                             Unsupported
# February 9, 2009                               Unsupported
# April 27, 2009                                 Unsupported
# September 15, 2009                             Unsupported
# October 26, 2009                               Unsupported
# May 20, 2010                                   Unsupported
# December 6, 2010                               Unsupported
# February 22, 2011                              Unsupported
# October 18, 2011                               Unsupported
# July 9, 2012                                   Unsupported
# October 31, 2013                               Unsupported
# November 12, 2014                                Supported
# October 5, 2015                                  Supported
# August 22, 2016                                  Supported
# August 21, 2017                                  Supported
# NaN                   Developer preview; not yet supported
# NaN                                                    NaN
# NaN                                                    NaN

# %% [markdown]
# 使用`skipfooter`参数忽略尾注。但因C解析器不支持该参数，会回退到Python解析器，可能导致其他问题。首先在Windows上编码会出现错误，因此显式指定编码为'utf-8'。

# %%
data = pd.read_table('test-data2.txt', skipfooter=2, encoding='utf-8')
data
# Out:
# f:\venvs\data-analysis\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                                                                                                       Code name
# (No codename)                      1.0         September 23, 2008 1                                 Unsupported
# (Internally known as "Petit Four") 1.1         February 9, 2009   2                                 Unsupported
# Cupcake                            1.5         April 27, 2009     3                                 Unsupported
# Donut                              1.6         September 15, 2009 4                                 Unsupported
# Eclair                             2.0 – 2.1   October 26, 2009   5 – 7                             Unsupported
# Froyo                              2.2 – 2.2.3 May 20, 2010       8                                 Unsupported
# Gingerbread                        2.3 – 2.3.7 December 6, 2010   9 – 10                            Unsupported
# Honeycomb                          3.0 – 3.2.6 February 22, 2011  11 – 13                           Unsupported
# Ice Cream Sandwich                 4.0 – 4.0.4 October 18, 2011   14 – 15                           Unsupported
# Jelly Bean                         4.1 – 4.3.1 July 9, 2012       16 – 18                           Unsupported
# KitKat                             4.4 – 4.4.4 October 31, 2013   19 – 20                           Unsupported
# Lollipop                           5.0 – 5.1.1 November 12, 2014  21 – 22                             Supported
# Marshmallow                        6.0 – 6.0.1 October 5, 2015    23                                  Supported
# Nougat                             7.0 – 7.1.2 August 22, 2016    24 – 25                             Supported
# Oreo                               8.0 – 8.1   August 21, 2017    26 – 27                             Supported
# Android P                          9           NaN                NaN      Developer preview; not yet supported

# %% [markdown]
# 头部解析明显出了错误，因此改用手动指定头部

# %%
data = pd.read_table('test-data2.txt', skipfooter=2, encoding='utf-8', header=None, skiprows=1)
data.columns='Code name	Version number	Initial release date	API level	Security patches'.split('\t')
data
# Out:
# f:\venvs\data-analysis\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                              Code name Version number Initial release date  \
# 0                        (No codename)            1.0   September 23, 2008
# 1   (Internally known as "Petit Four")            1.1     February 9, 2009
# 2                              Cupcake            1.5       April 27, 2009
# 3                                Donut            1.6   September 15, 2009
# 4                               Eclair      2.0 – 2.1     October 26, 2009
# 5                                Froyo    2.2 – 2.2.3         May 20, 2010
# 6                          Gingerbread    2.3 – 2.3.7     December 6, 2010
# 7                            Honeycomb    3.0 – 3.2.6    February 22, 2011
# 8                   Ice Cream Sandwich    4.0 – 4.0.4     October 18, 2011
# 9                           Jelly Bean    4.1 – 4.3.1         July 9, 2012
# 10                              KitKat    4.4 – 4.4.4     October 31, 2013
# 11                            Lollipop    5.0 – 5.1.1    November 12, 2014
# 12                         Marshmallow    6.0 – 6.0.1      October 5, 2015
# 13                              Nougat    7.0 – 7.1.2      August 22, 2016
# 14                                Oreo      8.0 – 8.1      August 21, 2017
# 15                           Android P              9                  NaN
#
#    API level                      Security patches
# 0          1                           Unsupported
# 1          2                           Unsupported
# 2          3                           Unsupported
# 3          4                           Unsupported
# 4      5 – 7                           Unsupported
# 5          8                           Unsupported
# 6     9 – 10                           Unsupported
# 7    11 – 13                           Unsupported
# 8    14 – 15                           Unsupported
# 9    16 – 18                           Unsupported
# 10   19 – 20                           Unsupported
# 11   21 – 22                             Supported
# 12        23                             Supported
# 13   24 – 25                             Supported
# 14   26 – 27                             Supported
# 15       NaN  Developer preview; not yet supported

# %% [markdown]
# 另一个workaround是，只读取需要的行数，避免使用`skipfooter`

# %%
data = pd.read_table('test-data2.txt', nrows=16)
data
# Out:
#                              Code name Version number Initial release date  \
# 0                        (No codename)            1.0   September 23, 2008
# 1   (Internally known as "Petit Four")            1.1     February 9, 2009
# 2                              Cupcake            1.5       April 27, 2009
# 3                                Donut            1.6   September 15, 2009
# 4                               Eclair      2.0 – 2.1     October 26, 2009
# 5                                Froyo    2.2 – 2.2.3         May 20, 2010
# 6                          Gingerbread    2.3 – 2.3.7     December 6, 2010
# 7                            Honeycomb    3.0 – 3.2.6    February 22, 2011
# 8                   Ice Cream Sandwich    4.0 – 4.0.4     October 18, 2011
# 9                           Jelly Bean    4.1 – 4.3.1         July 9, 2012
# 10                              KitKat    4.4 – 4.4.4     October 31, 2013
# 11                            Lollipop    5.0 – 5.1.1    November 12, 2014
# 12                         Marshmallow    6.0 – 6.0.1      October 5, 2015
# 13                              Nougat    7.0 – 7.1.2      August 22, 2016
# 14                                Oreo      8.0 – 8.1      August 21, 2017
# 15                           Android P              9                  NaN
#
#    API level                      Security patches
# 0          1                           Unsupported
# 1          2                           Unsupported
# 2          3                           Unsupported
# 3          4                           Unsupported
# 4      5 – 7                           Unsupported
# 5          8                           Unsupported
# 6     9 – 10                           Unsupported
# 7    11 – 13                           Unsupported
# 8    14 – 15                           Unsupported
# 9    16 – 18                           Unsupported
# 10   19 – 20                           Unsupported
# 11   21 – 22                             Supported
# 12        23                             Supported
# 13   24 – 25                             Supported
# 14   26 – 27                             Supported
# 15       NaN  Developer preview; not yet supported
